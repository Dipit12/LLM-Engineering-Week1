# %%
## lets start by making an call to an local LLM running through ollama
# !ollama pull gemma3
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(model='gemma3', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# Okay, let's break down why the sky is blue! It's a fascinating phenomenon related to how light interacts with our atmosphere. Here's the explanation:
#
# **1. Sunlight and Color:**
#
# * White sunlight is actually made up of *all* the colors of the rainbow – red, orange, yellow, green, blue, indigo, and violet.  You can see this when sunlight passes through a prism and separates into a spectrum.
#
# **2. Rayleigh Scattering:**
#
# * As sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen). This collision causes the light to scatter in different directions.
# * **This scattering is strongest for shorter wavelengths of light – blue and violet.**  This is called *Rayleigh scattering*.  Think of it like bouncing small balls (light waves) off of small obstacles. Shorter, smaller waves bounce off more easily and in all directions.
#
# **3. Why Blue, Not Violet?**
#
# * Violet light actually has the shortest wavelength and is scattered *even more* than blue light. However, there are a couple of reasons we see the sky as blue rather than violet:
#     * **Sunlight Intensity:** The sun emits less violet light than blue light.
#     * **Our Eyes are Less Sensitive to Violet:** Our eyes are simply more sensitive to blue light than violet light.
#
#
# **In short:** Blue light gets scattered more effectively by air molecules in the atmosphere, and this scattered blue light reaches our eyes from all directions, making the sky appear blue.
#
# **Think of it like this:**  Imagine throwing a handful of small marbles (blue light) and large golf balls (red light) at a bumpy wall. The smaller marbles will bounce off in all directions, while the larger golf balls will mostly keep going straight.
#
# ---
#
# **Resources for Further Learning:**
#
# * **NASA - Why is the sky blue?:** [https://science.nasa.gov/sky-observing/why-is-the-sky-blue/](https://science.nasa.gov/sky-observing/why-is-the-sky-blue/)
# * **National Geographic - Why is the Sky Blue?:** [https://www.nationalgeographic.org/encyclopedia/sky](https://www.nationalgeographic.org/encyclopedia/sky)
#
#
# Do you want me to explain anything in more detail, like:
#
# *   Why sunsets are red/orange?
# *   How this relates to other scattering phenomena (Mie scattering)?
# Okay, let's break down why the sky is blue! It's a fascinating phenomenon related to how light interacts with our atmosphere. Here's the explanation:
#
# **1. Sunlight and Color:**
#
# * White sunlight is actually made up of *all* the colors of the rainbow – red, orange, yellow, green, blue, indigo, and violet.  You can see this when sunlight passes through a prism and separates into a spectrum.
#
# **2. Rayleigh Scattering:**
#
# * As sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen). This collision causes the light to scatter in different directions.
# * **This scattering is strongest for shorter wavelengths of light – blue and violet.**  This is called *Rayleigh scattering*.  Think of it like bouncing small balls (light waves) off of small obstacles. Shorter, smaller waves bounce off more easily and in all directions.
#
# **3. Why Blue, Not Violet?**
#
# * Violet light actually has the shortest wavelength and is scattered *even more* than blue light. However, there are a couple of reasons we see the sky as blue rather than violet:
#     * **Sunlight Intensity:** The sun emits less violet light than blue light.
#     * **Our Eyes are Less Sensitive to Violet:** Our eyes are simply more sensitive to blue light than violet light.
#
#
# **In short:** Blue light gets scattered more effectively by air molecules in the atmosphere, and this scattered blue light reaches our eyes from all directions, making the sky appear blue.
#
# **Think of it like this:**  Imagine throwing a handful of small marbles (blue light) and large golf balls (red light) at a bumpy wall. The smaller marbles will bounce off in all directions, while the larger golf balls will mostly keep going straight.
#
# ---
#
# **Resources for Further Learning:**
#
# * **NASA - Why is the sky blue?:** [https://science.nasa.gov/sky-observing/why-is-the-sky-blue/](https://science.nasa.gov/sky-observing/why-is-the-sky-blue/)
# * **National Geographic - Why is the Sky Blue?:** [https://www.nationalgeographic.org/encyclopedia/sky](https://www.nationalgeographic.org/encyclopedia/sky)
#
#
# Do you want me to explain anything in more detail, like:
#
# *   Why sunsets are red/orange?
# *   How this relates to other scattering phenomena (Mie scattering)?
